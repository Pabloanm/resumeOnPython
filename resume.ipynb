# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my github.'
Name = 'Pablo Núñez Monzón'
Title = 'Backend developer & Project manager'
Contact = 'Buenos Aires, AR\n+54-9-11-6569-0856\npabloanm@gmail.com\nlinkedin.com/in/pabloanm/\ngithub.com/Pabloanm'
AboutMe = 'About Me'
AboutMeOneTitle = ''
AboutMeOneDesc = '¡Hi! I\'m passionate about emerging technologies, I have more than 10 years as\nsoftware developer on a variety of technical and creative projects.\nPrimarily interested in getting to be the best of what I can be.'
AboutMeTwoTitle = 'Essential Skillset'
AboutMeTwoDesc = '''- Ability to translate business requirements into design solutions
- Use data visualization to determine correlations for future study
- Good analytical, conceptual, and problem-solving abilities
- Experience using software delivery tools (e.g. JIRA / MS Project)
- Ability to work with technical and business teams alike understanding the 
difference in language to support effective delivery'''
#ProjectThree = ''
ProjectThreeDesc = ''
#Portfolio = 'Portfolio: pabloanm.com.ar'
WorkHeader = 'Employment History'
WorkOneTitle = 'UNSAM / Graduate Research And Teaching Assistant'
WorkOneTime = '01/2022-Present'
WorkOneDesc = '''- Working with large volumes of data
- Monitor project progress and set deadlines
- Ensure Stakeholder satisfaction
- Python, SQL, BigQuery, Data Science'''
WorkTwoTitle = 'Freelancer / Software Developer'
WorkTwoTime = '03/2012-Present'
WorkTwoDesc = '''- Project lifecycle management
- Requirements analysis
- Budget administration
- Agile framework
- Product development
- Infrastructure development
- Risk mitigation planning
- Php & Laravel, Javascript, Python & Django'''
WorkThreeTitle = 'AIPET / Solutions Manager'
WorkThreeTime = '08/2008-Present'
WorkThreeDesc = '''- Developing creative business solutions, leveraging diverse methodologies and 
delivering engineering solutions for leading organizations on energy sector 
- PHP, Python, JavaScript, C++, HTML5, CSS3, Sass, NodeJS, Angular, 
MySQL and MongoDB, Amazon server management Web Services, Git, SSH,
Docker + Compose, configuration of crons and shell scripts'''
EduHeader = 'Education'
EduOneTitle = 'CAECE University, Bachelor of Business and Systems Administration'
EduOneTime = '2016-2021'
EduOneDesc = '- Grade: 8'
EduTwoTitle = 'UTN FRBA University, Computer Software Engineering'
EduTwoTime = '2003-2008'
EduTwoDesc = '- Intermediate analyst\'s degree in systems'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Matplotlib\n- ETL\n- Git and Version Control\n- APIs\n- Probability/Statistics\n- Django+REST\n- fastAPI\n- Flask\n- Php\n- Javascript\n- Databases, SQL + NoSQL\n- Docker + Compose'
ExtrasTitle = '''I’m currently learning
Data Analytics'''
#ExtrasDesc = 'Learned popular data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis'
#CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(AboutMe, (.02,.88), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(AboutMeOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(AboutMeOneDesc, (.04,.82), weight='regular', fontsize=9)
plt.annotate(AboutMeTwoTitle, (.04,.790), weight='bold', fontsize=10)
plt.annotate(AboutMeTwoDesc, (.04,.68), weight='regular', fontsize=9)
#plt.annotate(ProjectThree, (.02,.672), weight='regular', fontsize=9)
plt.annotate(ProjectThreeDesc, (.04,.638), weight='regular', fontsize=9)
#plt.annotate(Portfolio, (.02,.6), weight='bold', fontsize=10)
plt.annotate(WorkHeader, (.02,.63), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.600), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.580), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.510), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.48), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.460), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.330), weight='regular', fontsize=9)
plt.annotate(WorkThreeTitle, (.02,.300), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkThreeDesc, (.04,.195), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.170), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.140), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.12), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.100), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.07), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.052), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoDesc, (.04,.035), weight='regular', fontsize=9)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.50), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
#plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=10, color='#ffffff')
#plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')

'''
#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('ekresumecode.png')
imagebox = OffsetImage(arr_code, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.84, 0.12))
ax.add_artist(ab)
'''

plt.savefig('resumeexample.png', dpi=300, bbox_inches='tight')
